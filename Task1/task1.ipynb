# %% [markdown]
# **IMPORT PANDAS**

# %%
import pandas as pd

# %% [markdown]
# **DATA READING**

# %%
data_read = pd.read_csv('Shopping Mall Customer Segmentation Data .csv')

# %%
data_read
# Out:
#                                 Customer ID  Age  Gender  Annual Income  \
# 0      d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1      1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2      e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3      9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4      64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
# ...                                     ...  ...     ...            ...
# 15074  a0504768-a85f-4930-ac24-55bc8e4fec9e   29  Female          97723
# 15075  a08c4e0e-d1fe-48e7-9366-aab11ae409cd   22    Male          73361
# 15076  0e87c25a-268c-401a-8ba1-7111dcde6f1a   18  Female         112337
# 15077  5f388cbe-3373-4e16-b743-38f508f2249f   26  Female          94312
# 15078  b8b8f561-ebca-4401-8afe-544c906554ba   19    Male          78045
#
#        Spending Score
# 0                  89
# 1                  95
# 2                  76
# ...

# %% [markdown]
# **CHECKING NULL VALUES**

# %%
data_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  object
#  1   Age             15079 non-null  int64
#  2   Gender          15079 non-null  object
#  3   Annual Income   15079 non-null  int64
#  4   Spending Score  15079 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 589.2+ KB

# %% [markdown]
# **REMOVING DUPLICATES**

# %%
data_read = data_read.drop_duplicates()
data_read
# Out:
#                                 Customer ID  Age  Gender  Annual Income  \
# 0      d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1      1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2      e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3      9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4      64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
# ...                                     ...  ...     ...            ...
# 15074  a0504768-a85f-4930-ac24-55bc8e4fec9e   29  Female          97723
# 15075  a08c4e0e-d1fe-48e7-9366-aab11ae409cd   22    Male          73361
# 15076  0e87c25a-268c-401a-8ba1-7111dcde6f1a   18  Female         112337
# 15077  5f388cbe-3373-4e16-b743-38f508f2249f   26  Female          94312
# 15078  b8b8f561-ebca-4401-8afe-544c906554ba   19    Male          78045
#
#        Spending Score
# 0                  89
# 1                  95
# 2                  76
# ...

# %% [markdown]
# **CLEANING AGE COLUMN**

# %%
data_read['Age'] = data_read['Age'].astype(str).str.replace('[a-zA-Z]','')

# %% [markdown]
# **REPLACING NULL VALUES AS UNKNOWN**

# %%
data_read = data_read.fillna('Unknown')

# %% [markdown]
# **ARRANGING AGE IN ASSENDING ORDER**

# %%
data_read = data_read.sort_values(by='Age', ascending=True)
data_read
# Out:
#                                 Customer ID Age  Gender  Annual Income  \
# 8749   eb065f9c-09b7-4a7e-9ca1-b464f30f312d  18    Male          84470
# 8654   f36ba0c9-31bb-466a-a2b2-c506e7886860  18    Male         183255
# 8670   63397ec3-4ff2-4d8a-acf9-f9d11f680c77  18    Male          56951
# 8705   0b589709-bd15-4e5c-b532-fba8984031c5  18  Female         145042
# 1318   c0f0086a-efc1-4fc8-aaf9-90a1dc98e640  18  Female         145216
# ...                                     ...  ..     ...            ...
# 11083  a8b20526-a3a6-4223-9b24-e47330f87bf7  90    Male         125458
# 4010   ed15310d-4022-430c-bf0c-7a014f3599c3  90    Male          22404
# 11094  2f7d56e9-59d3-4ef4-b2f7-bf10d5302027  90    Male          90490
# 719    c1b20dff-0ce8-429a-9d0d-f93b7eed447d  90    Male         163256
# 13613  f4cb184c-cdc2-41a8-89df-10da4e818f06  90    Male         189256
#
#        Spending Score
# 8749               39
# 8654               84
# 8670               30
# ...

# %% [markdown]
# **CREATING AGE GROUP**

# %%
bins = [0, 25, 35, 45, 55, 100]
labels = ['Young', 'Adult', 'Middle Age', 'Older Adult', 'Senior']

# %%
data_read['Age'] = pd.to_numeric(data_read['Age'], errors='coerce')
data_read['Age_Group'] = pd.cut(data_read['Age'], bins=bins, labels=labels, right=False)
data_read
# Out:
#                                 Customer ID  Age  Gender  Annual Income  \
# 8749   eb065f9c-09b7-4a7e-9ca1-b464f30f312d   18    Male          84470
# 8654   f36ba0c9-31bb-466a-a2b2-c506e7886860   18    Male         183255
# 8670   63397ec3-4ff2-4d8a-acf9-f9d11f680c77   18    Male          56951
# 8705   0b589709-bd15-4e5c-b532-fba8984031c5   18  Female         145042
# 1318   c0f0086a-efc1-4fc8-aaf9-90a1dc98e640   18  Female         145216
# ...                                     ...  ...     ...            ...
# 11083  a8b20526-a3a6-4223-9b24-e47330f87bf7   90    Male         125458
# 4010   ed15310d-4022-430c-bf0c-7a014f3599c3   90    Male          22404
# 11094  2f7d56e9-59d3-4ef4-b2f7-bf10d5302027   90    Male          90490
# 719    c1b20dff-0ce8-429a-9d0d-f93b7eed447d   90    Male         163256
# 13613  f4cb184c-cdc2-41a8-89df-10da4e818f06   90    Male         189256
#
#        Spending Score Age_Group
# 8749               39     Young
# 8654               84     Young
# ...

# %% [markdown]
# **Alligning the Columns**

# %%
cols = list(data_read.columns)
cols.remove('Age_Group')
age_index = cols.index('Age')
cols.insert(age_index + 1, 'Age_Group')
data_read = data_read[cols]
data_read
# Out:
#                                 Customer ID  Age Age_Group  Gender  \
# 8749   eb065f9c-09b7-4a7e-9ca1-b464f30f312d   18     Young    Male
# 8654   f36ba0c9-31bb-466a-a2b2-c506e7886860   18     Young    Male
# 8670   63397ec3-4ff2-4d8a-acf9-f9d11f680c77   18     Young    Male
# 8705   0b589709-bd15-4e5c-b532-fba8984031c5   18     Young  Female
# 1318   c0f0086a-efc1-4fc8-aaf9-90a1dc98e640   18     Young  Female
# ...                                     ...  ...       ...     ...
# 11083  a8b20526-a3a6-4223-9b24-e47330f87bf7   90    Senior    Male
# 4010   ed15310d-4022-430c-bf0c-7a014f3599c3   90    Senior    Male
# 11094  2f7d56e9-59d3-4ef4-b2f7-bf10d5302027   90    Senior    Male
# 719    c1b20dff-0ce8-429a-9d0d-f93b7eed447d   90    Senior    Male
# 13613  f4cb184c-cdc2-41a8-89df-10da4e818f06   90    Senior    Male
#
#        Annual Income  Spending Score
# 8749           84470              39
# 8654          183255              84
# 8670           56951              30
# ...

# %%
data_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15079 entries, 8749 to 13613
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  object
#  1   Age             15079 non-null  int64
#  2   Age_Group       15079 non-null  category
#  3   Gender          15079 non-null  object
#  4   Annual Income   15079 non-null  int64
#  5   Spending Score  15079 non-null  int64
# dtypes: category(1), int64(3), object(2)
# memory usage: 721.8+ KB

# %%
data_read.describe()
# Out:
#                 Age  Annual Income  Spending Score
# count  15079.000000   15079.000000    15079.000000
# mean      54.191591  109742.880562       50.591617
# std       21.119207   52249.425866       28.726977
# min       18.000000   20022.000000        1.000000
# 25%       36.000000   64141.000000       26.000000
# 50%       54.000000  109190.000000       51.000000
# 75%       72.000000  155008.000000       75.000000
# max       90.000000  199974.000000      100.000000

# %% [markdown]
# **DOWNLOADING DATASET**

# %%
data_read.to_csv('Cleaned_Shopping_Data.csv', index=False)

# %%
from google.colab import files
files.download('Cleaned_Shopping_Data.csv')
